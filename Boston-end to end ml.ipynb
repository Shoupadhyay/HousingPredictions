# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path='/Users/shobhitupadhyay/HousingData.csv.xls'
boston=pd.read_csv(file_path)

# %%
boston.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.describe
# Out:
# <bound method NDFrame.describe of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
dataset=pd.DataFrame(boston)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset['price']=dataset['MEDV']

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  price
# 0  396.90   4.98  24.0   24.0
# 1  396.90   9.14  21.6   21.6
# 2  392.83   4.03  34.7   34.7
# 3  394.63   2.94  33.4   33.4
# 4  396.90    NaN  36.2   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
#  14  price    506 non-null    float64
# dtypes: float64(13), int64(2)
# memory usage: 59.4 KB

# %%
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# price       0
# dtype: int64

# %%
df = dataset.dropna(subset=['CRIM','ZN','INDUS','CHAS','AGE','LSTAT'])

# Display the resulting DataFrame
print(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV  price
# 0       15.3  396.90   4.98  24.0   24.0
# 1       17.8  396.90   9.14  21.6   21.6
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# ...

# %%
df.drop('MEDV', axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %%
plt.scatter(df['CRIM'],df['price'])

# %%
plt.scatter(df['RM'],df['price'])

# %%
import seaborn as sns
sns.regplot(x='RM',y='price',data=df)
# Out:
# <Axes: xlabel='RM', ylabel='price'>

# %%
sns.regplot(x='PTRATIO',y='price',data=df)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='price'>

# %%
X=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: price, Length: 394, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=48)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 99    0.06860   0.0   2.89   0.0  0.445  7.416   62.5  3.4952    2  276
# 424   8.79212   0.0  18.10   0.0  0.584  5.565   70.6  2.0635   24  666
# 175   0.06664   0.0   4.05   0.0  0.510  6.546   33.1  3.1323    5  296
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705   24  666
# 45    0.17142   0.0   6.91   0.0  0.448  5.682   33.8  5.1004    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 412  18.81100   0.0  18.10   0.0  0.597  4.628  100.0  1.5539   24  666
# 447   9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980   24  666
# 434  13.91340   0.0  18.10   0.0  0.713  6.208   95.0  2.2222   24  666
# 61    0.17171  25.0   5.13   0.0  0.453  5.966   93.4  6.8185    8  284
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296
#
#      PTRATIO       B  LSTAT  MEDV
# 99      18.0  396.90   6.19  33.2
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.4348634 , -0.47831123, -1.1541094 , ...,  0.43102175,
#         -0.86131049,  1.15996643],
#        [ 0.72739466, -0.47831123,  1.04475872, ..., -4.22071955,
#          0.59306515, -1.16890773],
#        [-0.43512454, -0.47831123, -0.98641137, ...,  0.36075769,
#         -0.97532718,  0.74835146],
#        ...,
#        [ 1.40971659, -0.47831123,  1.04475872, ..., -3.07354632,
#          0.32923584, -1.16890773],
#        [-0.42112578,  0.59720462, -0.83027872, ...,  0.20840059,
#          0.23245423, -0.7031329 ],
#        [-0.44316113,  0.29606018, -1.23795841, ...,  0.43102175,
#         -1.02172932,  0.16342493]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression =LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg_pred=regression.predict(X_test)

# %%
## plot a  scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
residual=y_test-reg_pred# error

# %%
sns.displot(residual,kind="kde")

# %%
#scatter wrt pred vs error
plt.scatter(reg_pred,residual)

# %%
## performance metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_absolute_error(y_test,reg_pred)))
# Out:
# 1.7450093657637756e-14
# 1.7450093657637756e-14
# 1.3209880263514032e-07

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 1.0

# %%
# Out:
# /Users/shobhitupadhyay/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cf/wk0b8fm13m39pyr_81b2jcdr0000gn/T/ipykernel_25019/2816796987.py in <module>
# ----> 1 scaler.transform(dataset.iloc[0].values.reshape(1, -1))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# ...

# %%
df.shape[1]
# Out:
# 14

# %%
scaler.transform(df.iloc[0].values.reshape(1, -1))
# Out:
# /Users/shobhitupadhyay/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.44316113,  0.29606018, -1.23795841, -0.26464865, -0.13701231,
#          0.39998991, -0.12715835,  0.12332661, -0.97358496, -0.64070188,
#         -1.50038258,  0.43102175, -1.02172932,  0.16342493]])

# %%
regression.predict(scaler.transform(df.iloc[0].values.reshape(1,-1)))
# Out:
# /Users/shobhitupadhyay/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([24.])

# %%
## deployment
import pickle
pickle.dump(regression,open('regression.pkl','wb'))

# %%
model=pickle.load(open('regression.pkl','rb'))

# %%
model.predict(scaler.transform(df.iloc[0].values.reshape(1,-1)))
# Out:
# /Users/shobhitupadhyay/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([24.])

# %%
# Out:
# Input columns: ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
# Expected columns: ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
# Input columns match expected columns
